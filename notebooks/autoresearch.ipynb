# %%
# === AUTORESEARCH CONFIG ===
METRIC_NAME = "vocab_retention_7d"
METRIC_TARGET = 0.6
METRIC_DIRECTION = "maximize"
# === END CONFIG ===
# SM-2 simulation; tune ease/interval.

# %%
import random
random.seed(11)
# Simulated SM-2 spaced-rep learner over 7 days; baseline ~52% retention.
words = 100
retained = sum(1 for _ in range(words) if random.random() < 0.52)
final_value = retained / words
print(f'vocab_retention_7d={final_value:.4f}')

# %%
print(f'Target {METRIC_TARGET}, current {final_value}')
print(f'METRIC: {METRIC_NAME}={final_value}')
